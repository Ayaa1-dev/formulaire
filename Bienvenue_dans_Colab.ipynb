# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayaa1-dev/formulaire/blob/main/Bienvenue_dans_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
datajeux = pd.read_csv('Data.csv') #recuperation du dataset
X = datajeux.iloc[:, :-1].values #selection des variables ind
Y = datajeux.iloc[:, -1].values #

# %%
print(Y)
# Out:
# ['Non' 'Oui' 'Non' 'Non' 'Oui' 'Oui' 'Non' 'Oui' 'Non' 'Oui']

# %%
from sklearn.impute import SimpleImputer
valeursmanquantes = SimpleImputer(missing_values = np.na)
valeursmanquantes.fix(X[:, 1:3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1896752601.py in <cell line: 0>()
#       1 from sklearn.impute import SimpleImputer
#       2 valeursmanquantes = SimpleImputer(missing_values = np.nan)
# ----> 3 valeursmanquantes.fix(X[:, 1:3])
#
# AttributeError: 'SimpleImputer' object has no attribute 'fix'
